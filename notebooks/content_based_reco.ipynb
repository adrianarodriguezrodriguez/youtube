# %% [markdown]
# # Content-Based Recommendations

# %%
# %run ../src/utils.py

# %%
# %run ../src/plots.py

# %%
set_seed()

# %%
data = initialize_data()

# %% [markdown]
# # Make recommendations by title and video tags

# %% [markdown]
# 1.Combines the titles and tags .
#
# 2.TF-IDF numerical vectors.
#
# 3.Similarity between videos —cosine similarity
#
# 4.Displays the most similar videos to a given one

# %%
matrix = generate_matrix(data)

# Function to recommend by video name, preventing it from recommending itself
recomendar_videos_por_nombre(data, matrix, "PA TONAZ", top_n=4)
# Out:
# Recommended videos for 'PA TONAZ':
# - Vučić prekinuo intervju Veljka Ražnatovića pa zbunio i nasmejao boksera (Similarity: 1.00)
# - PA, AKU CAPEK... (Similarity: 1.00)
# - ELAI - Pa To (Similarity: 1.00)
# - GÅR DET ATT RYMMA FRÅN POLISEN PÅ LISEBERG? (Similarity: 1.00)

# %% [markdown]
# # Neural Network

# %%
y, y_test, y_pred = generate_neural_network(data)

# %%
plot_neural_network_results(y, y_test, y_pred)

# %% [markdown]
# The red line represents x=y (perfect sol).
#
# X = what actually happened
#
# Y = what your model said would happen
#
# 🔴 If the point is close to the red line:
# ➡️ The model was pretty accurate.
#
# 🔴 If it's far from the line:
# ➡️ The model was more incorrect (it predicted a value that was very different from the actual value).
